# %%
import pandas as pd

obj = pd.read_pickle('/Users/morganoneka/Box/My Stuff/CLAM/results/task_1_tumor_vs_normal_CLAM_50_s1_s1/split_0_results.pkl')

# %%
! pip install torch
# Out:
# ...
#      |████████████████████████████████| 127.9MB 8.2MB/s eta 0:00:01    |██████████████████              | 71.7MB 6.6MB/s eta 0:00:09
# ...

# %%
import torch
vocab = torch.load('/Users/morganoneka/Box/My Stuff/CLAM/results/task_1_tumor_vs_normal_CLAM_50_s1_s1/s_0_checkpoint.pt', map_location=torch.device('cpu'))

# %%
vocab
# Out:
# OrderedDict([('attention_net.0.weight',
#               tensor([[ 0.0396, -0.0468, -0.0491,  ..., -0.0358,  0.0925, -0.0252],
#                       [-0.0452, -0.0120, -0.0007,  ...,  0.0367,  0.0232, -0.0064],
#                       [ 0.0262,  0.0339, -0.0054,  ...,  0.0391, -0.0209,  0.0155],
#                       ...,
#                       [-0.0457,  0.0404, -0.0353,  ..., -0.0333,  0.0188, -0.0099],
#                       [ 0.0008,  0.0078,  0.0252,  ..., -0.0726, -0.0131,  0.0053],
#                       [ 0.0098, -0.0033,  0.0238,  ..., -0.0021, -0.0059,  0.0220]])),
#              ('attention_net.0.bias',
#               tensor([ 8.9922e-04,  9.2165e-03, -1.9664e-03, -1.2288e-03,  3.3749e-03,
#                       -1.9098e-03, -2.8512e-03,  8.0354e-03, -4.3830e-03, -9.4237e-03,
#                        4.0015e-03,  5.6765e-03, -5.9930e-03,  4.2795e-02, -2.4510e-03,
#                        5.7221e-03,  4.5062e-04, -1.4034e-03,  0.0000e+00, -1.6108e-03,
# ...
